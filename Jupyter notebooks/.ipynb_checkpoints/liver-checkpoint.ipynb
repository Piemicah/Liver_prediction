# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import seaborn as sn
import matplotlib.pyplot as plt
import joblib

# %%
liver=pd.read_csv('Liver Patient Data.csv')

# %%
liver.head()
# Out:
#     Age  Gender  Total Bilirubin  Direct Bilirubin  Alkphos  Sgpt   Sgot  \
# 0  65.0  Female              0.7               0.1    187.0  16.0   18.0
# 1  62.0    Male             10.9               5.5    699.0  64.0  100.0
# 2  62.0    Male              7.3               4.1    490.0  60.0   68.0
# 3  58.0    Male              1.0               0.4    182.0  14.0   20.0
# 4  72.0    Male              3.9               2.0    195.0  27.0   59.0
#
#    Total Protiens  ALB Albumin   A/G  Result
# 0             6.8          3.3  0.90       1
# 1             7.5          3.2  0.74       1
# 2             7.0          3.3  0.89       1
# 3             6.8          3.4  1.00       1
# 4             7.3          2.4  0.40       1

# %%
liver.shape
# Out:
# (30691, 11)

# %%
liver.isnull().sum()
# Out:
# Age                   2
# Gender              902
# Total Bilirubin     648
# Direct Bilirubin    561
# Alkphos             796
# Sgpt                538
# Sgot                462
# Total Protiens      463
# ALB Albumin         494
# A/G                 559
# Result                0
# dtype: int64

# %%
liver=liver.dropna()

# %%
liver.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Total Bilirubin     0
# Direct Bilirubin    0
# Alkphos             0
# Sgpt                0
# Sgot                0
# Total Protiens      0
# ALB Albumin         0
# A/G                 0
# Result              0
# dtype: int64

# %%
liver.shape
# Out:
# (27158, 11)

# %% [markdown]
# ## Transform Gender to numerical data

# %%
le=LabelEncoder()

# %%
liver['Sex']=liver[['Gender']].apply(le.fit_transform)

# %%
liver.head()
# Out:
#     Age  Gender  Total Bilirubin  Direct Bilirubin  Alkphos  Sgpt   Sgot  \
# 0  65.0  Female              0.7               0.1    187.0  16.0   18.0
# 1  62.0    Male             10.9               5.5    699.0  64.0  100.0
# 2  62.0    Male              7.3               4.1    490.0  60.0   68.0
# 3  58.0    Male              1.0               0.4    182.0  14.0   20.0
# 4  72.0    Male              3.9               2.0    195.0  27.0   59.0
#
#    Total Protiens  ALB Albumin   A/G  Result  Sex
# 0             6.8          3.3  0.90       1    0
# 1             7.5          3.2  0.74       1    1
# 2             7.0          3.3  0.89       1    1
# 3             6.8          3.4  1.00       1    1
# 4             7.3          2.4  0.40       1    1

# %%
liver['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
liver['Result'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,8))
sn.heatmap(liver.corr(),annot=True,fmt='1.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### It can be seen clearly that 'Age' and "Gender" have no correlation with other columns.

# %% [markdown]
# ### Drop "Age","Gender" and "Sex" respectively

# %%
liver=liver.drop(columns=['Age','Sex','Gender'])

# %%
liver.head()
# Out:
#    Total Bilirubin  Direct Bilirubin  Alkphos  Sgpt   Sgot  Total Protiens  \
# 0              0.7               0.1    187.0  16.0   18.0             6.8
# 1             10.9               5.5    699.0  64.0  100.0             7.5
# 2              7.3               4.1    490.0  60.0   68.0             7.0
# 3              1.0               0.4    182.0  14.0   20.0             6.8
# 4              3.9               2.0    195.0  27.0   59.0             7.3
#
#    ALB Albumin   A/G  Result
# 0          3.3  0.90       1
# 1          3.2  0.74       1
# 2          3.3  0.89       1
# 3          3.4  1.00       1
# 4          2.4  0.40       1

# %%
sn.pairplot(liver)

# %% [markdown]
# ### Separate input from output

# %%
x=liver.drop(columns='Result')

# %%
y=liver[['Result']]

# %%
x.head()
# Out:
#    Total Bilirubin  Direct Bilirubin  Alkphos  Sgpt   Sgot  Total Protiens  \
# 0              0.7               0.1    187.0  16.0   18.0             6.8
# 1             10.9               5.5    699.0  64.0  100.0             7.5
# 2              7.3               4.1    490.0  60.0   68.0             7.0
# 3              1.0               0.4    182.0  14.0   20.0             6.8
# 4              3.9               2.0    195.0  27.0   59.0             7.3
#
#    ALB Albumin   A/G
# 0          3.3  0.90
# 1          3.2  0.74
# 2          3.3  0.89
# 3          3.4  1.00
# 4          2.4  0.40

# %%
y.head()
# Out:
#    Result
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[0.5,0.1,187,16,18,6.8,3.6,0.8]])
# Out:
# array([2], dtype=int64)

# %%
def predict(a):
    r=model.predict(a)
    if r[0]==1: return 'Have Liver Problem'
    else: return 'No Liver Problem'

# %%
predict([[0.7,0.1,187,16,18,6.8,3.3,0.9]])
# Out:
# 'Have Liver Problem'

# %%
model.score(x_test,y_test)*100
# Out:
# 99.98527245949927

# %%
joblib.dump(model,'liver_predictor.joblib')
# Out:
# ['liver_predictor.joblib']
